# %% [markdown]
# <a id="top"></a>
# ### <span style="color: red;"></span>

# %% [markdown]
# ### &diams; <span style="color: green;">Highlight </span>
# <ul style="margin-left: 40px; color: green; font-size:20px;">
#     <li style="color: darkviolet; font-style: italic;">Aggregate Production<a href="#ap">🔗</a></li>
#     <li style="color: deepskyblue; font-style: italic;">Aggregate Expenditure<a href="#ae">🔗</a></li>
#     <li style="color: green; font-style: italic;">Consumption Expenditures <a href="#ce">🔗</a></li>
#     <li style="color: royalblue; font-style: italic;">Investment Expenditures<a href="#ie">🔗</a></li>
#     <li style="color: fuchsia; font-style: italic;">Government Spending Expenditures<a href="#gse">🔗</a></li>
#     <li style="color: blue; font-style: italic;">Net Export Expenditures<a href="#ne">🔗</a></li>
#     <!-- <li style="color: darkgray; font-style: italic;">Aggregate Production<a href="#advsas">🔗</a></li> -->
#     <!-- <li style="color: fuchsia; font-style: italic;"> -->
#      <!-- Key Idea: Keynesian Model Assumption (Hansen/Samuelson version): Prices are Fixed!!! 🧐 -->
#       <!--  <a href="#kmhski">🔗</a> -->
# </ul>
#
#
# <!--
#     <li style="color: darkturquoise; font-style: italic; padding-left: 20px; list-style-type: none; text-indent: -1.5em; display: flex; align-items: center; justify-content: center; margin-left: 1em;">-->
# <!--
#         <span style="font-size: 1.0em;">&#9734</span> Key Idea: Keynesian Model Assumption (Hansen/Samuelson version): Prices are Fixed!!! <a href="#kmhski">🔗</a>
# </li>
# -->

# %% [markdown]
# <a id="ap"></a>
#
# <span style="color: darkviolet; font-size: 30px; font-weight: bold;">Aggregate Production</span>
#
# <ul style="list-style-type: disc; margin-left: 20px; font-size: 18px; color: darkturquoise; font-weight: bold;">
#     <li>Defined as Total Amount of Goods and Services Producted in the Economy</li>
#     <li>It is 45 degree line</li>
# </ul>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact
import ipywidgets as widgets

# Function to update the plot
def update_plot(AEe=1500, Q_line=600):
    # Clear the previous plot
    plt.clf()

    # Real GDP (Output) range
    GDP = np.linspace(0, 1200, 100)

    # Calculate the equilibrium point Qe from AEe
    # AE = 0.8 * GDP + b
    # At equilibrium, AE = Y = X ==> AEe = Qe
    Qe = AEe  # At equilibrium, AE = Qe

    # The slope of AE is calculated as m = (AEe - 200) / Qe
    m = (AEe - 200) / Qe  # The slope of AE changes dynamically with AEe

    # The intercept b is then calculated from AE = 0.8 * Qe + b => b = AEe - m * Qe
    b = AEe - m * Qe

    # Aggregate Expenditures function
    AE = m * GDP + b

    # Aggregate Production (the 45-degree line)
    production = GDP  # Y = X line, representing Aggregate Production

    # Plotting the graph
    plt.figure(figsize=(8, 6))

    # Plot the Aggregate Expenditures (AE) line
    plt.plot(GDP, AE, label="Aggregate Expenditures (AE = C + I + G + X)", color='blue', linewidth=2)

    # Plot the Aggregate Production (45-degree line)
    plt.plot(GDP, production, label="Aggregate Production (Y = X)", color='red', linestyle='--', linewidth=2)

    # Plot the equilibrium point
    plt.scatter(Qe, AEe, color='green', zorder=5)  # Equilibrium point (Qe, AEe)
    plt.text(Qe + 30, AEe - 30, f'Equilibrium\n(Qe={Qe:.2f}, AEe={AEe})', color='green', fontsize=12)

    # Draw the vertical line from the equilibrium point to the y-axis (AEe line)
    #plt.plot([Qe, Qe], [0, AEe], color='green', linestyle=':', label="AEe Line")
    plt.plot([Qe, Qe], [0, AEe], color='green', linestyle=':')
    
    # Draw the horizontal line from the equilibrium point to the x-axis (Qe line)
    #plt.plot([0, Qe], [AEe, AEe], color='green', linestyle=':', label="Qe Line")
    plt.plot([0, Qe], [AEe, AEe], color='green', linestyle=':')

    # Plot the vertical line based on Q_line slider value
    plt.axvline(x=Q_line, color='purple', linestyle='-', linewidth=2, label=f"Production Potential")

    # Set the limits of the axes so the green lines touch the axes
    plt.xlim(0, max(Qe, Q_line) + 100)  # Extend the x-limits based on Qe and Q_line
    plt.ylim(0, max(AEe, Q_line) + 100)  # Extend the y-limits based on AEe and Q_line

    # Adding labels and title
    plt.title('Aggregate Expenditures vs. Real GDP Output', fontsize=14)
    plt.xlabel('Real GDP Output', fontsize=12)
    plt.ylabel('Aggregate Expenditures (AE)', fontsize=12)

    # Displaying the legend and grid
    plt.legend(loc="upper left")
    #plt.grid(True)

    # Show the plot
    plt.show()

# Create a slider for AEe value adjustment
slider_AEe = widgets.FloatSlider(
    value=1000,  # Initial value of AEe
    min=0,       # Minimum value
    max=1500,    # Maximum value
    step=10,     # Step size
    description='AE Level:',
    continuous_update=False
)

# Create a slider for Q_line value adjustment
slider_Q_line = widgets.FloatSlider(
    value=600,  # Initial value of Q_line
    min=0,      # Minimum value
    max=1200,   # Maximum value
    step=10,    # Step size
    description='Production Potential (Q Line):',
    continuous_update=False
)

# Create an interactive plot with both sliders
interact(update_plot, AEe=slider_AEe, Q_line=slider_Q_line)
# Out:
# interactive(children=(FloatSlider(value=1000.0, continuous_update=False, description='AE Level:', max=1500.0, …
# <function __main__.update_plot(AEe=1500, Q_line=600)>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="ae"></a>
#
# <span style="color: deepskyblue; font-size: 30px; font-weight: bold;">Aggregate Expenditure</span>
#
# <ul style="list-style-type: disc; margin-left: 20px; font-size: 18px; color: darkturquoise; font-weight: bold;">
#     <li>AE = Consumption + Investment + Gov't Spending + Net Exports (X - M)</li>
#     <li>Define as vertical sumation of the FOUR componenets listed above</li>
# </ul>
#
#
#
# ### &diams; <span style="color: blue;">Aggregate Expenditures Curve</span>
#
# <div style="margin-left: 40px;">
#    <!-- Bullet points with diamond shape before text -->
#    <p style="margin-left: 15px; color: Fuchsia; font-size: 20px; font-weight: bold;">
#       &#9674; A flatter slope than 45 degree line of the Aggregate Production Curve
#    </p>
#    <p style="margin-left: 15px; color: Fuchsia; font-size: 20px; font-weight: bold;">
#       &#9674; Autonomous Consumption
#    </p>
#        <div style="margin-left: 30px;font-size: 18px">
#           &#9678; <span style="color: darkviolet;">Intercepts the vertical axis above zero</span><br>
#           &#9678; <span style="color: darkviolet;">Even if income is zero, ppl will spend a certain amount of money on consumption (aka Autonomous Consumption), happening independently of the level of income</span><br>
#        </div>
# </div>
#
#   <div style="margin-left: 20px;font-size: 15px">
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Expansionary</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">Increased Govn't Expenditures</span><br>
#           &#9678; <span style="color: teal;">Tax Cut</span><br>
#        </div>
#            <div style="margin-left: 30px;font-size: 18px">
#               &#9758; <span style="color: brown;font-weight:bold;">Fight Recession (Fiscal Stimulus)</span>
#            </div>
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Intercepts the vertical axis above zero</span>
#         <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">Even if incomes is zero, ppl will spend a certain amount of money on consumption (aka Autonomous Consumption), happening independently of the level of income</span><br>
#           &#9678; <span style="color: teal;">Tax Hike</span><br>
#        </div>
#            <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#9758; <span style="color: brown;font-weight:bold;">Fight Inflation</span>
#            </div>
#     </div>
# </div>
#
#
# ### &diams; <span style="color: red;">Why does Aggregate Expenditures curve have a flatter slope than Aggregate Production curve?</span>
# ### &diams; <span style="color: red;">How can Autonomous Consumption exist when Income is Zero</span>
#
# #### Reasons:
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">1. Consumtion accounts for the largest portion of AE</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Durable Goods (i.e. autos, household equipment...)</span><br>
#         </div>
#     </div>
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">2. Logic of Autonomous Consumption</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Dip into savings to consume, even when no income (i.e. laid off)</span><br>
#         </div>
#     </div>
#      <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">3. Induced Consumption</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;"></span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Defined as the Level of consumption that depends on an individual's disposable income</span><br>                  </div>
#     </div>
#               <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">4 Disposable Income</span>
#              <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;"></span><br> -->
#              <div style="margin-left: 20px; font-size: 18px;">
#                 &#9678; <span style="color: teal;">Defined as the Amount of income left after paying taxes</span><br>
#                 &#9678; <span style="color: teal;">Marginal Propensity to Consume is less than one</span><br>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="ce"></a>
#
# <span style="color: green; font-size: 30px; font-weight: bold;">Consumption Expenditure</span>
#
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">1. Autonomous Consumtion</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;">Expansionary</span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Durable Goods (i.e. autos, household equipment...)</span><br>
#             &#9678; <span style="color: teal;">Non-Durable Goods (i.e. good and clothing)</span><br>
#             &#9678; <span style="color: teal;">Services (i.e. public transportation, medical care)</span><br>
#         </div>
#         <div style="margin-left: 30px; font-size: 18px;">
#             <!-- &#9758; <span style="color: brown; font-weight: bold;">Fight Recession</span> -->
#         </div>
#     </div>
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">2. Induced Consumption</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;"></span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Dip into savings to consume</span><br>
#         </div>
#     </div>
#      <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">3. Marginal Propensity Consumption (or expend) (MPC)</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;"></span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Defined as the extra amount ppl consume when they receive an extra dollar of disposable income</span><br>
#             &#9678; <span style="color: teal;">Marginal Propensity to Consume is less than one</span><br> </div>
#     </div>
#          <div style="margin-left: 40px;">
#              <span style="color: orange; font-size: 20px; font-weight: bold;">3.1 Marginal Propensity to Save (MPS)</span>
#            <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;"></span><br> -->
#           <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Defined as the extra amount ppl save when they receive an extra dollar of disposable income</span><br>
#         </div>
#     </div>
# </div>
#
# # <span style="color: purple;">Algebra of Consumption Function</span>
#
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">C = Co + MPC*Yd</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;">Expansionary</span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">C: Consumption</span><br>
#             &#9678; <span style="color: teal;">Co: Autonomous Consumption</span><br>
#             &#9678; <span style="color: teal;">MPC: Marginal Propensity to Consume</span><br>
#             &#9678; <span style="color: teal;">Yd: Disposable Income</span><br>
#             &#9678; <span style="color: teal;">Consumption = Autonomous Consumption + Induced Consumption</span><br>
#         </div>
#     </div>
# </div>
#
#
# ### &#9835; <span style="color: dodgerblue;">Under Classical theory, the 45 degree line can represent as Consumption = Disposable Income. Yet, from MPC/MPS, it indicates AE curve is flatter than the "Ideal Classical Theory", which is why Thomas Malthus critiqued its reality.</span>
#
#
# ### &#10084; <span style="color: dodgerblue;">With a holistic review, was Classifical theory wrong or inadequate to capture the society then? Or was it due to the change of the living prompted to the change of the modification of the theory and thus Thomas' revision of the Classifical theory worked for such a time like this?🧐</span>
#
# ### &#10080; <span style="color: blue;">The proof with the plot in the lecture was a pessmistic approach, using MPC less than one example to support the statement of why the slope is less than 1 🤨</span>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="ie"></a>
# # <span style="color: royalblue;">Investment Expenditures</span>
#
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">1. Plant + Equipment</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;">Expansionary</span><br> -->
#         <div style="margin-left: 30px; font-size: 18px;">
#             <!-- &#9758; <span style="color: brown; font-weight: bold;">Fight Recession</span> -->
#         </div>
#     </div>
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">2. Inventory</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#             &#8594; <span style="color: deepskyblue; font-weight:bold;">Over-forecast Aggregate Demand</span><br>
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Build-up excess inventory</span><br>
#             &#9678; <span style="color: teal;">Slash production, Lay off workers</span><br>
#         </div>
#             <div style="margin-left: 30px;font-size: 18px">
#               &#9758; <span style="color: brown;font-weight:bold;">Trigger Economic Slowdown</span><br>
#               &#9758; <span style="color: brown;font-weight:bold;">Forecast is crucial at both comapny and national levels</span>
#            </div>
#     </div>
#      <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">3.Business investment Assumed to be Autonomous</span>
#      <div style="margin-left: 30px;font-size: 18px">
#               &#8594; <span style="color: deepskyblue;font-weight:bold;">In the Keynesian Framework</span><br>
#               </span>
#                  <div style="margin-left: 20px; font-size: 18px;">
#                     &#9678; <span style="color: teal;">Indepentently, assumed to occur of the level of income</span><br>
#                     &#9678; <span style="color: teal;">Algebraically, assumed to occur autonomously</span><br>
#                 </div>
#            </div>
# </div>
# </div>
#
# ### &diams; <span style="color: red;">Draw the Keynesian model Investment Function, assuming invesetment equals autonomous investment</span>
#
# #### Result:
#
# <div style="margin-left: 40px;">
#     <span style="color: blue; font-size: 20px; font-weight: bold;">&#9870; A Horizontal Line</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">As not depending on the income, given the contraint / assumption of the question</span><br>
#         </div>
#     </div>
# </div>
#
# ### &diams; <span style="color: red;">What determines the level of the investment, if not by income?</span>
#
# #### Reasons:
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">1. Changes of Interest Rates</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">When the rates fall (the fall of financial capital), it results in an increase in investment. In other words, investment expenditures rise as it becomes cheaper to invest</span><br>
#             &#9678; <span style="color: teal;">When the rates rise (the rise of financial capital), it results in a decrease in investment. In other words, investment expenditures fall as it becomes more expensive to undertake captial investment</span><br>
#         </div>
#     <span style="color: blue; font-size: 20px; font-weight: bold;">&#9750; Classical View</span>
#     <div style="margin-left: 30px; font-size: 18px;">
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9688; <span style="color: teal;">Falling interest rates and increased investment lead back to full employment</span><br>
#         </div>
#     </div>
#     <span style="color: blue; font-size: 20px; font-weight: bold;">&#9750; Keynes View</span>
#     <div style="margin-left: 30px; font-size: 18px;">
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9688; <span style="color: teal;">Animal Spirits</span><br>
#         </div>
#     </div>
#     </div>
#      <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">2. Expectation (Animal Spirits)</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;"></span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Driven by expectation</span><br>
#         </div>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;"></span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9698; <span style="color: gold;font-weight:bold;">Bearish market</span><br>
#         </div>
#          <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;"></span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9672; <span style="color: royalblue;">Cut Production</span><br>
#             &#9672; <span style="color: royalblue;">Reduce Investment</span><br>
#             &#9672; <span style="color: royalblue;">Trim Inventories</span><br>
#             &#9672; <span style="color: royalblue;">Layoffs</span><br>
#              <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#9758; <span style="color: brown;font-weight:bold;">Trigger / Amplify Recession</span>
#               &#9758; <span style="color: brown;font-weight:bold;">Confidenc Index is a key indicator</span>
#            </div>
#         </div>
#             &#9698; <span style="color: gold;font-weight:bold;">Bullish market</span><br>
#         </div>
#     </div>
#     </div>
#     </div>
# </div>
#
#
# # <span style="color: purple;">Algebra of Investment Function (Keynes Framework)</span>
#
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">I = Io + E*</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;">Expansionary</span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">I: Investment</span><br>
#             &#9678; <span style="color: teal;">Io: Autonomous Investment</span><br>
#             &#9678; <span style="color: teal;">E*: Businesses + Consumers Expectation</span><br>
#         </div>
#     </div>
# </div>
#
#
# ### &#9835; <span style="color: dodgerblue;">Under Classical theory, the market can return to equilibrium quickly once ppl act according to interest rate policy</span>
#
#
# ### &#10084; <span style="color: dodgerblue;">With Keynesian view, the market is more sophisticated than just being leveraged by the interest rate policy. Expectation of the market sentiment plays an important role in bringing back to the equilibrium level as well.🧐</span>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="gse"></a>
#
# # <span style="color: fuchsia;">Government Spending Expenditures</span>
#
# ### In a nutshell:
# <div style="margin-left: 40px;">
#     <span style="color: darkgray; font-size: 20px; font-weight: bold;">&#8658;Provide needed public goods and services </span>
#     <div style="margin-left: 20px; font-size: 18px;">
#     </div>
#     <span style="color: darkgray; font-size: 20px;font-weight: bold;">&#8658;A "balance wheel" of fiscal policy to fight slow growth oro recession</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#     </div>
# </div><br>
#
# ### Specifications:
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">1. Purchases</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#             &#8594; <span style="color: teal;">National Defense</span><br>
#         <div style="margin-left: 30px; font-size: 18px;">
#             <!-- &#9758; <span style="color: brown; font-weight: bold;">Fight Recession</span> -->
#         </div>
#     </div>
#     <span style="color: Fuchsia; font-size: 20px;font-weight: bold;">2. Infrastructure</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#             &#8594; <span style="color: teal;">Public Roads</span><br>
#     </div>
#      <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">3.Payments / Salaries for the Fed workers</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#     </div>
#      <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">4.Autonomous Assumption in Keynesian Model</span>
#      <div style="margin-left: 30px;font-size: 18px">
#               </span>
#                  <div style="margin-left: 20px; font-size: 18px;">
#                     &#96678; <span style="color: teal;">Indepentently, assumed to occur of the level of income</span><br>
#                     &#9678; <span style="color: teal;">Algebraically, assumed to occur autonomously</span><br>
#                 </div>
#            </div>
#      <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">5.Gov't Expenditures Less Volatile than Business Investment</span>
#      <div style="margin-left: 30px;font-size: 18px">
#               &#8594; <span style="color: deepskyblue;font-weight:bold;">Episodic Events (i.e. wars, natural disasters) can lead to huge fluctuations</span><br>                              </div>
# </div>
# </div>
#
# ### &diams; <span style="color: red;">Draw the Keynesian model Government Function, assuming Government Spending equals autonomous Gon't Spending</span>
#
# #### Result:
#
# <div style="margin-left: 40px;">
#     <span style="color: blue; font-size: 20px; font-weight: bold;">&#9870; A Horizontal Line</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">As not depending on the income, given the contraint / assumption of the question</span><br>
#         </div>
#     </div>
# </div>
#
# ### &diams; <span style="color: red;">What would be the Keynesian approach to fight recession, in terms of discretionary fiscal policy?</span>
#
# #### Recommendations:
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">&#8594;Expansionary Fiscal Policy</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Increase Govn't Expenditures</span><br>
#             &#9678; <span style="color: teal;">Tax Cuts</span><br>
#         </div>
#     </div>
# </div>
#
# ### &diams; <span style="color: red;">What would be the Keynesian approach to fight recession, in terms of NON-discretionary fiscal policy?</span>
#
# #### Recommendations:
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">&#8594;Non-discretionary Expenditure Can Serve As "Automatic Stabilizers" </span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Unemployment Compensation for workers</span><br>
#             &#9678; <span style="color: teal;">Welfare Payments</span><br>
#             &#9678; <span style="color: teal;">Subsidies to Farmers that automatically rise or fall depending on economic conditions</span><br>
#         </div>
#     </div>
# </div>
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">&#8594; Automatic Stabilizer </span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Define as gov't programs that automatically increase spending to fight recession and decrease gov't spending to control inflation</span><br>
#             &#9678; <span style="color: teal;">For instance: in recession, workers got laid off, unemployment compensation rises, automatic boost to Govn't Spending helps Statblize Economy</span><br>
#         </div>
#     </div>
# </div>
#
# # <span style="color: purple;">Algebra of Government Spending Function (Keynes Framework)</span>
#
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">G = Go</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;">Expansionary</span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">G: Gov't Spending</span><br>
#             &#9678; <span style="color: teal;">Go: Autonomous Gov't Spending</span><br>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <a id="ne"></a>
# # <span style="color: blue;">Net Export Expenditures</span>
#
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">1. Export</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: deepskyblue;">Creates Domestic Production, Income, Employment</span><br>
#         <div style="margin-left: 30px; font-size: 18px;">
#             <!-- &#9758; <span style="color: brown; font-weight: bold;">Fight Recession</span> -->
#         </div>
#     </div>
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">2. Import</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: deepskyblue;">No Domestic Production, Income, Employment</span><br>
#     </div>
#      <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">3.Trade Surplus / Deficit </span>
#      <div style="margin-left: 30px;font-size: 18px">
#               &#8594; <span style="color: deepskyblue;font-weight:bold;">When Exports > Imports (Surplus)</span><br>
#               </span>
#                  <div style="margin-left: 20px; font-size: 18px;">
#                     &#9678; <span style="color: teal;">Add to GDP growth </span><br>
#                 </div>
#           &#8594; <span style="color: deepskyblue;font-weight:bold;">When Exports < Imports (Deficit)</span><br>
#               </span>
#                  <div style="margin-left: 20px; font-size: 18px;">
#                     &#9678; <span style="color: teal;">Subtract from GDP growth </span><br>
#                 </div>
#            </div>
# </div>
# </div>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>
