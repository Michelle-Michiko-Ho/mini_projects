# %% [markdown]
# <a id="top"></a>
# ### <span style="color: red;"></span>

# %% [markdown]
# ### &diams; <span style="color: green;">Highlight </span>
# <ul style="margin-left: 40px; color: green; font-size:20px;">
#     <li style="color: darkviolet; font-style: italic;">Keynesian Expenditures Multiplier<a href="#kem">🔗</a></li>
#     <li style="color: deepskyblue; font-style: italic;">Keynesian Tax Multiplier<a href="#ktm">🔗</a></li>
#     <!-- <li style="color: darkgray; font-style: italic;">Aggregate Production<a href="#advsas">🔗</a></li> -->
#     <li style="color: fuchsia; font-style: italic;">
#         History Backdrop: What Triggered Great Depression: 1929<a href="#gd">🔗</a>
#     </li>
#     <li style="color: dodgerblue; font-style: italic;">
#         History Backdrop: What Caused Banking Crisis: 2023<a href="#2023">🔗</a>
#     </li>
#     <li style="color: darkturquoise; font-style: italic;">
#         Spinning Idea: Crowding Out! <a href="#co">🔗</a>
#     </li>
# </ul>

# %% [markdown]
# <a id="kem"></a>
#
# <span style="color: darkviolet; font-size: 30px; font-weight: bold;">The Keynesian Expenditure Multiplier</span>
#
# ### &#9822; <span style="color: blue;">Keynesian Expenditure Multiplier is a number by which a change in aggregate expenditures must be mutiplied in order to determine the resulting change in total output</span>
#
#
# ### &#9832; <span style="color: royalblue;">Practice: In increasing total output by $100 Billion with a Keynesian Multiplier of 4, what amount is needed to increase in AE?</span>
#
# <div style="margin-left: 20px;font-size: 20px; margin-top: -10px;">
#        <span style="color: royalblue;font-weight:bold;;">&#9758; $25 Billion</span><br><br>
#       </div>
#
# <div style="margin-left: 0px;">
#    <span style="color: Fuchsia; font-size: 20px;font-weight: bold;">Keynesian Expenditure Multiplier is always greater than ONE</span>
#    <div style="margin-left: 20px;font-size: 15px">
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Income is spent</span><br>
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Not just sonce, but many times after the inital increase</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9888; <span style="color: brown; font-wiehgt: bold;">The process deepens recession when an initial reduction in demand kicks-in (i.e. a shock)</span><br>
#     </div>
# </div><br>
#
# <span style="color: black; font-size:20px;">$\text{Keynesia Expenditures Multiplier} = \frac{1}{\text{MPS}} = \frac{1}{\text{1- MPC}}$
#
#
# <table style="float: left; border: 1px solid black; border-collapse: collapse;text-align: center;">
#   <tr>
#     <th style="border: 1px solid black; padding: 5px;">MPC</th>
#     <th style="border: 1px solid black; padding: 5px;">Multiplier</th>
#   </tr>
#   <tr>
#     <td style="border: 1px solid black; padding: 5px;">0.9</td>
#     <td style="border: 1px solid black; padding: 5px;">10</td>
#   </tr>
#     <tr>
#     <td style="border: 1px solid black; padding: 5px;">0.8</td>
#     <td style="border: 1px solid black; padding: 5px;">5</td>
#   </tr>
#     <tr>
#     <td style="border: 1px solid black; padding: 5px;">0.75</td>
#     <td style="border: 1px solid black; padding: 5px;">4</td>
#   </tr>
#     <tr>
#     <td style="border: 1px solid black; padding: 5px;">0.5</td>
#     <td style="border: 1px solid black; padding: 5px;">2</td>
#   </tr>
# </table>
#
# <div style="clear: both;"></div>
#
# <span style="color: blue;font-size:20px;">&#10023;The bigger the MPC, the less ppl are saving</span>
# <div style="margin-left: 0px;font-size: 20px; margin-top: -20px;">
# <span style="color: blue;">&#10023;The larger will be the multiplier, and the more effective fiscal policy will be.</span>
# </div><br>
#
# ### Paradox of Thrift
#
# <span style="color: darkturquoise;font-size:20px;font-weight:bold;">&#10023;Echoing back in that the savings represent a major leakage of the economy...</span>
# <div style="margin-left: 0px;font-size: 20px; margin-top: -20px;">
# <span style="color: darkturquoise;font-size:20px;font-weight:bold;">&#10023;The more thrifty a society is, the less effective fiscal policy may be</span>
# </div><br>
#
# <span style="font-size:20px; color:black;">Paradox of Thrift</span>
# <span style="font-size:30px;">&#8658;</span>
# <span style="font-size:20px; color:black;">Recession Hits</span>
# <span style="font-size:30px;">&#8658;</span>
# <span style="font-size:20px; color:black;">Cautious Consumers Save More</span>
# <span style="font-size:30px;">&#8658;</span>
# <span style="font-size:20px; color:black;">Consumption Falls</span>
# <span style="font-size:30px;">&#8658;</span>
# <span style="font-size:20px; color:black;">Production falls</span>
# <span style="font-size:30px;">&#8658;</span>
# <span style="font-size:20px; color:black;">Workers Laidoff</span>
# <span style="font-size:30px;">&#8658;</span>
# <span style="font-size:20px; color:black;">Income Falls</span>
# <span style="font-size:30px;">&#8658;</span>
# <span style="font-size:20px; color:black;">People wind up saving less</span>
#
#
#
#
# ### &diams; <span style="color: red;">What is the slope of the Aggregate Expenditure curve, assuming in a closed economy,leaving out the Net Export?</span>
#
# #### Reasons:
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">&#10148;Same as the Consumption Function Slope (MPC)</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;">Expansionary</span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Invesetment Expenditure is a horizontal line</span><br>
#             &#9678; <span style="color: teal;">Govn't Spending Expenditure is a horizontal line</span><br>
#          </div>
#     </div>
# </div>
#
#
# # <span style="color: brown;">ScenarioA</span>
#
# - **<span style="color: darkgray;font-size:20px;">Ques: The Full Employment output is $100 Billion, yet the current output is 70 Billion. What is the underlying of the economy?</span>**
# <div style="margin-left: 40px;">
#   <span style="color: green;font-size:20px;font-weight:bold;"> &#9758;There is a recessionary gap of 30 Billion</span>
# </div>
#
# ### &#9835; <span style="color: dodgerblue;">The beauty of the Keyesian Model is that it helps us determine how fiscal policy can quite precisely close that recessionary gap</span>
#
# # <span style="color: blue;">ScenarioB</span>
#
# - **<span style="color: darkviolet;font-size: 20px;">Ques: The Full Employment output is $100 Billion, yet the current output is 70 Billion. MPC=0.8. What is the underlying increase of Govn't Spending in order to close the gap?</span>**
# <div style="margin-left: 40px;">
#   <span style="color: green; font-size:20px;font-weight:bold;"> &#9758;There is a recessionary gap of 6 (30/(1-0.8) Billion</span>
# </div>
#
# # <span style="color: Orange;">ScenarioC</span>
#
# - **<span style="color: dodgerblue;font-size: 20px;">Ques: The Full Employment output is $100 Billion, yet the current output is 120 Billion. MPC=0.8. What is the underlying decrease of Govn't Spending in order to close the gap?</span>**
# <div style="margin-left: 40px;">
#   <span style="color: fuchsia; font-size:20px;font-weight:bold;"> &#9758;There is a recessionary gap of 4 (20/(1-0.8) Billion</span>
# </div>

# %%
import matplotlib.pyplot as plt

# Define the data for the bins
mpc = 0.5
bins = [100, 50, 25, 12.5, 6.25]

# Create the histogram
plt.hist(bins, bins=5, edgecolor='black', alpha=0.7)

# Add labels and title
plt.title("Histogram of Values Based on MPC (0.5)")
plt.xlabel("Value")
plt.ylabel("Frequency")

# Show the plot
plt.show()

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="ktm"></a>
#
# <span style="color: deepskyblue; font-size: 30px; font-weight: bold;">Keynesian Tax Multiplier</span>
#
# ### &#9822; <span style="color: blue;">In Keynesian Theory, Tax cut has less expansionary effect than Govn't Expenditures bc consumers save some of that tax cut, based on their marginal propensity to save (MPS)</span>
#
#
# <div style="margin-left: 40px;">
#    <span style="color: Fuchsia; font-size: 20px;font-weight: bold;">Keynesian Tax Multiplier (KTM)</span>
#    <div style="margin-left: 20px;font-size: 15px">
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Keynesian Expendiures Multiplier(KEM)</span><br>
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Marginal Propensity to Consume(MPC)</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">KTM = KEM * MPC</span><br>
#        </div>
#            <!-- <div style="margin-left: 30px;font-size: 18px"> -->
#             <!-- &#9758; <span style="color: brown;font-weight:bold;">Fight Recession</span> -->
#            <!-- </div> -->
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Recessionary Gaps</span>
#         <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">Defined as wgeb Real GDP/Output < Potential GDP / Output</span><br>
#        </div>
#            <!-- <div style="margin-left: 30px;font-size: 18px; font-style: bold;"> -->
#            <!--  &#9758; <span style="color: brown;font-weight:bold;">Fight Inflation</span> -->
#            <!-- </div> -->
#     </div>
# </div>
#
#
# ### &diams; <span style="color: red;">Why are there inflationary and recessionary gaps?</span>
#
# #### Reasons:
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">1. Leakages</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;">Expansionary</span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Defined as income not directly spent on domestic output but is diverted from the circular flow (AS=AD)</span><br>
#             &#9678; <span style="color: teal;">Savings (Consumer + Businesses)</span><br>
#             &#9678; <span style="color: teal;">Taxes (Consumer + Business)</span><br>
#             &#9678; <span style="color: teal;">Imports</span><br>
#             <div style="margin-left: 40px; font-size: 18px;">
#                 &#9657; <span style="color: darkviolet;">Savings can be influenced by factors like interest rates or consumer confidence</span><br>
#                 &#9657; <span style="color: darkviolet;">Government policies such as tax incentives can affect the level of leakages</span><br>
#             </div>
#         </div>
#         <div style="margin-left: 30px; font-size: 18px;">
#             <!-- &#9758; <span style="color: brown; font-weight: bold;">Fight Recession</span> -->
#         </div>
#     </div>
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">2. Injections</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;"></span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Defined as an addition of income to the circular flow</span><br>
#             &#9678; <span style="color: teal;">Business Investment </span><br>
#             &#9678; <span style="color: teal;">Gov't Spending</span><br>
#             &#9678; <span style="color: teal;">Exports</span><br>
#         </div>
#         <!-- <div style="margin-left: 30px; font-size: 18px;"> -->
#         <!--  &#9758; <span style="color: brown; font-weight: bold;">Fight Recession</span> -->
#         <!-- </div> -->
#     </div>
# </div>
#
# # <span style="color: brown;">ScenarioA</span>
#
# - **<span style="color: darkgray;font-size:20px;">Ques: The Full Employment output is $100 Billion, yet the current output is 70 Billion. What is the underlying of the economy?</span>**
# <div style="margin-left: 40px;">
#   <span style="color: green;font-size:20px;font-weight:bold;"> &#9758;There is a recessionary gap of 30 Billion</span>
# </div>
#
# # <span style="color: blue;">ScenarioB</span>
#
# - **<span style="color: darkviolet;font-size: 20px;">Ques: The Full Employment output is $100 Billion, yet the current output is 70 Billion. MPC=0.8. What is the underlying increase of Tax Cut in order to close the gap?</span>**
# <div style="margin-left: 40px;">
#   <span style="color: green; font-size:20px;font-weight:bold;"> &#9758;There is a recessionary gap of 7.5 (30 * Tax Multiplier) Billion</span>
#     <div style="margin-left: 50px;">
#         <span style="color: green; font-size:20px;font-weight:regular;"> &#9758;Tax Multiplier = 4 = (1/(1-0.8))*0.8 Billion</span>
# </div>
#
# # <span style="color: Orange;">ScenarioC</span>
#
# - **<span style="color: dodgerblue;font-size: 20px;">Ques: The Full Employment output is $100 Billion, yet the current output is 120 Billion. MPC=0.8. What is the underlying decrease of Tax Cut in order to close the gap?</span>**
# <div style="margin-left: 40px;">
#   <span style="color: fuchsia; font-size:20px;font-weight:bold;"> &#9758;There is a recessionary gap of 5 (20/(1-0.8) Billion</span>
#     <div style="margin-left: 50px;">
#         <span style="color: green; font-size:20px;font-weight:regular;"> &#9758;Tax Multiplier = 4 = (1/(1-0.8))*0.8 Billion</span>
# </div>
#
#
# ## Key Takeaway?
# ### <span style="font-size: 28px; font-weight: bold;">&#9788;</span> <span style="color: green;">Macroeconomic Equilibrium depends on balance between injections and leakages.</span>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact
import ipywidgets as widgets

# Function to update the plot
def update_plot(AEe=1500, Q_line=600):
    # Clear the previous plot
    plt.clf()

    # Real GDP (Output) range
    GDP = np.linspace(0, 1200, 100)

    # Calculate the equilibrium point Qe from AEe
    # AE = 0.8 * GDP + b
    # At equilibrium, AE = Y = X ==> AEe = Qe
    Qe = AEe  # At equilibrium, AE = Qe

    # The slope of AE is calculated as m = (AEe - 200) / Qe
    m = (AEe - 200) / Qe  # The slope of AE changes dynamically with AEe

    # The intercept b is then calculated from AE = 0.8 * Qe + b => b = AEe - m * Qe
    b = AEe - m * Qe

    # Aggregate Expenditures function
    AE = m * GDP + b

    # Aggregate Production (the 45-degree line)
    production = GDP  # Y = X line, representing Aggregate Production

    # Plotting the graph
    plt.figure(figsize=(8, 6))

    # Plot the Aggregate Expenditures (AE) line
    plt.plot(GDP, AE, label="Aggregate Expenditures (AE = C + I + G + X)", color='blue', linewidth=2)

    # Plot the Aggregate Production (45-degree line)
    plt.plot(GDP, production, label="Aggregate Production (Y = X)", color='red', linestyle='--', linewidth=2)

    # Plot the equilibrium point
    plt.scatter(Qe, AEe, color='green', zorder=5)  # Equilibrium point (Qe, AEe)
    plt.text(Qe + 30, AEe - 30, f'Equilibrium\n(Qe={Qe:.2f}, AEe={AEe})', color='green', fontsize=12)

    # Draw the vertical line from the equilibrium point to the y-axis (AEe line)
    plt.plot([Qe, Qe], [0, AEe], color='green', linestyle=':', label="AEe Line")
    
    # Draw the horizontal line from the equilibrium point to the x-axis (Qe line)
    plt.plot([0, Qe], [AEe, AEe], color='green', linestyle=':', label="Qe Line")

    # Plot the vertical line based on Q_line slider value
    plt.axvline(x=Q_line, color='purple', linestyle='-', linewidth=2, label=f"Production Potential")

    # Set the limits of the axes so the green lines touch the axes
    plt.xlim(0, max(Qe, Q_line) + 100)  # Extend the x-limits based on Qe and Q_line
    plt.ylim(0, max(AEe, Q_line) + 100)  # Extend the y-limits based on AEe and Q_line

    # Adding labels and title
    plt.title('Aggregate Expenditures vs. Real GDP Output', fontsize=14)
    plt.xlabel('Real GDP Output', fontsize=12)
    plt.ylabel('Aggregate Expenditures (AE)', fontsize=12)

    # Displaying the legend and grid
    plt.legend()
    plt.grid(True)

    # Show the plot
    plt.show()

# Create a slider for AEe value adjustment
slider_AEe = widgets.FloatSlider(
    value=1000,  # Initial value of AEe
    min=0,       # Minimum value
    max=1500,    # Maximum value
    step=10,     # Step size
    description='AE Level:',
    continuous_update=False
)

# Create a slider for Q_line value adjustment
slider_Q_line = widgets.FloatSlider(
    value=600,  # Initial value of Q_line
    min=0,      # Minimum value
    max=1200,   # Maximum value
    step=10,    # Step size
    description='Production Potential (Q Line):',
    continuous_update=False
)

# Create an interactive plot with both sliders
interact(update_plot, AEe=slider_AEe, Q_line=slider_Q_line)
# Out:
# interactive(children=(FloatSlider(value=1000.0, continuous_update=False, description='AE Level:', max=1500.0, …
# <function __main__.update_plot(AEe=1500, Q_line=600)>

# %% [markdown]
# ## Key Takeaway?
# ### <span style="font-size: 28px; font-weight: bold;">&#9918;</span> <span style="color: deepskyblue;">When Production Potential is on the *right side* of equilibrium point, there is "Recessionary Gap"</span>
#
# ### <span style="font-size: 28px; font-weight: bold;">&#9918;</span> <span style="color: deepskyblue;">When Production potential is on the *left side* of the equlibrium point, there is "Inflationary Gap"</span>
#
# <span style="font-size: 18px;">&#9918;</span> <!-- Baseball -->
# <span style="font-size: 18px;">&#9917;</span> <!-- Soccer Ball -->
# <span style="font-size: 18px;">&#127936;</span> <!-- basketball  Ball -->
# ...

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="gd"></a>
#
# <span style="color: darkturquoise; font-size: 30px; font-weight: bold;">Great Depression: 1929</span>
#
#
# The Great Depression of 1929 was triggered by a combination of factors, many of which had been building over the preceding years. The immediate cause was the **stock market crash** in October 1929, but this event was part of a broader set of economic problems that made the economy vulnerable. Here’s a summary of the key factors that contributed to the onset of the Great Depression:
#
# ### 1. **The Stock Market Crash of 1929**
#    - **Black Thursday (October 24, 1929)** and **Black Tuesday (October 29, 1929)** were the most famous days of the stock market crash. Stock prices had been soaring through the 1920s, fueled by speculation. Many people were investing heavily in stocks using borrowed money (on margin), assuming prices would keep rising.
#    - When stock prices began to fall, panic selling ensued. This created a **vicious cycle**: falling stock prices led to more margin calls (requiring investors to repay their loans), which led to further sales and deeper declines.
#    - By the end of 1929, the stock market had lost nearly **90%** of its value.
#
# ### 2. **Overproduction and Underconsumption**
#    - During the 1920s, businesses, particularly in agriculture and manufacturing, were producing more goods than consumers could buy. This was partly due to **technological advances** that allowed for increased production, but wages for workers were not rising fast enough to keep up with the output.
#    - As a result, companies had **unsold inventory**, leading to layoffs and further reducing purchasing power in the economy. This created a **downward spiral** of reduced demand, falling wages, and increased unemployment.
#
# ### 3. **Bank Failures and Financial Instability**
#    - Many banks had invested heavily in the stock market, and when the market collapsed, they suffered huge losses. As a result, **thousands of banks failed** in the early years of the Depression.
#    - People panicked and rushed to withdraw their money, causing a **banking crisis**. By 1933, nearly **9,000 banks** had failed, which further eroded public confidence in the financial system.
#    - The lack of a central banking system to regulate monetary policy also contributed to the crisis. The Federal Reserve failed to act swiftly to prevent the crisis from spreading.
#
# ### 4. **Agricultural Collapse**
#    - The **1920s was a difficult time for farmers**. The demand for agricultural products had fallen after World War I, and many farmers were left with massive debt.
#    - In addition, the **Dust Bowl** (a series of severe droughts in the mid-1930s) devastated crops in the Great Plains, particularly in states like Oklahoma and Kansas. The agricultural sector, which was already struggling, was further harmed by environmental factors and economic mismanagement.
#
# ### 5. **Unequal Distribution of Wealth**
#    - Income inequality was a significant issue during the 1920s. A large portion of the wealth was concentrated in the hands of a small elite, while many Americans (especially workers) had little purchasing power.
#    - This disparity meant that even though the economy was producing a lot, the majority of people couldn't afford to buy the goods being produced, leading to **underconsumption**. When the economic downturn hit, the lack of a broad consumer base to sustain demand made recovery difficult.
#
# ### 6. **International Economic Factors**
#    - **The Smoot-Hawley Tariff (1930)**, passed by the U.S. Congress, raised tariffs on foreign goods in an effort to protect American industries. However, this backfired by causing other countries to retaliate with tariffs on American goods, leading to a **decline in international trade**.
#    - Many European countries were still recovering from the effects of World War I, and the global economy was weak. The U.S. also had invested heavily in European nations, and when the Depression hit, European markets collapsed, dragging down international trade further.
#
# ### 7. **Monetary Policy and the Gold Standard**
#    - The **Gold Standard** (which fixed the value of money to a specific amount of gold) also played a role. As the U.S. was on the Gold Standard, the Federal Reserve was limited in its ability to adjust the money supply to respond to the crisis. Instead of increasing liquidity, the Fed **raised interest rates** in an attempt to protect the value of the dollar, which worsened the crisis by contracting the money supply further.
#    - Many countries also remained on the Gold Standard, which meant they could not devalue their currencies or use fiscal policy effectively to counter the downturn.
#
# ### 8. **Weak Government Response**
#    - Initially, President **Herbert Hoover** believed that the market would recover on its own. His response to the crisis was generally seen as insufficient and ineffective. Hoover resisted large-scale government intervention and believed that local communities and businesses should solve the problems.
#    - However, as the crisis deepened, Hoover eventually attempted some measures like public works projects and government loans to businesses, but these were too little, too late to reverse the economic collapse.
#
# ### Summary: The Perfect Storm
# The Great Depression was caused by a **combination of economic mismanagement**, **financial instability**, **speculative excess**, and **global interconnectedness**. The stock market crash was the immediate trigger, but the underlying causes were structural problems that had been building up for years. The collapse of the financial system, coupled with agricultural and industrial overproduction, weak government responses, and international factors, led to an economic collapse that lasted for much of the 1930s.
#
# In response, the U.S. government, under **Franklin D. Roosevelt**, enacted a series of programs known as the **New Deal** to address the economic challenges, stabilize the banking system, and provide relief to the unemployed. The effects of the Depression were felt worldwide, and it took World War II and the wartime economy to finally pull many countries out of the depression.
#
# ###### Credit: ChatGPT

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="2023"></a>
#
# <span style="color: dodgerblue; font-size: 30px; font-weight: bold;">Banking Crisis: 2023</span>
#
# The banking crisis that unfolded in 2023, particularly with high-profile failures like **Silicon Valley Bank (SVB)** and **Signature Bank**, was caused by a combination of factors. These included rising interest rates, poor risk management, and a lack of confidence in the stability of some financial institutions. Here's a breakdown of the key factors that triggered the 2023 banking crisis:
#
# ### 1. **Rising Interest Rates and Bond Losses**
#    - The **Federal Reserve's aggressive interest rate hikes** throughout 2022 and 2023 were a central factor. In response to rising inflation, the Fed raised rates at a pace not seen in decades. The goal was to cool down the economy and bring inflation back to the target range.
#    - However, **higher interest rates** caused the value of long-term **bonds** (like U.S. Treasury bonds and mortgage-backed securities) to fall. Many banks, including SVB, had significant holdings in long-duration bonds. These assets lose value when interest rates rise, leading to **paper losses** in their portfolios.
#    - **Silicon Valley Bank**, for example, had a large proportion of its portfolio tied to U.S. government bonds, which it had bought when interest rates were low. When rates rose, the market value of these bonds dropped, leaving the bank with unrealized losses.
#
# ### 2. **Unrealized Losses and Liquidity Problems**
#    - As interest rates increased, many banks, including SVB, were sitting on **unrealized losses** on their bond portfolios. These losses were not immediately reflected in the banks’ financial statements, but they were a significant vulnerability.
#    - **SVB**'s client base was heavily concentrated in the **tech sector** and startups, which were facing a **funding squeeze** as venture capital funding slowed down due to higher borrowing costs. This led to a surge in **withdrawals** from SVB, as startups needed cash to cover expenses, and venture capital firms pulled funds to keep their operations going.
#    - To meet withdrawal demands, **SVB was forced to sell its bonds** at a loss, realizing the negative impact of rising interest rates. The realization of these losses caused concerns among its depositors and led to a **bank run**.
#
# ### 3. **Concentration of Clients and Lack of Diversification**
#    - **Silicon Valley Bank** had a very **concentrated client base**, with many of its depositors being **tech companies, startups, and venture capitalists**. When these clients started withdrawing funds due to the liquidity crunch in the tech sector, it had a **disproportionate impact** on the bank's stability.
#    - **Signature Bank**, similarly, had a high concentration of deposits from the **cryptocurrency sector**, which was also facing volatility in 2023. As the crypto market struggled, Signature Bank saw a large portion of its deposits withdrawn.
#    - The lack of **diversification** in client bases and in assets made these banks more vulnerable to sector-specific downturns and to macroeconomic pressures.
#
# ### 4. **Lack of Confidence and Bank Runs**
#    - The **collapse of SVB** triggered a broader loss of confidence in the banking sector. As news of SVB's troubles spread, depositors at other banks began to worry about their own financial institutions' stability.
#    - **Bank runs** can happen when depositors lose faith in a bank’s solvency and rush to withdraw their funds. Even though most banks are insured up to $250,000 by the **FDIC**, the fear of insolvency and loss of access to funds led to a rapid **exodus of deposits** from smaller banks.
#    - **Signature Bank** and other smaller banks faced similar runs in the aftermath of SVB's failure.
#
# ### 5. **Weaknesses in Risk Management**
#    - Many banks, including SVB, failed to adequately hedge against the risk posed by rising interest rates. Some financial institutions took on more risk than they should have, including holding large amounts of low-interest bonds that became devalued when rates rose.
#    - The failure to **manage interest rate risk** effectively, particularly when the Fed’s tightening cycle was underway, was a major oversight by banks. They didn't foresee the rapid pace of rate hikes or their impact on their bond portfolios and liquidity needs.
#
# ### 6. **Regulatory Oversight and Supervision**
#    - Some critics have pointed to **weak regulatory oversight** of certain banks, especially after the **deregulation** of the banking industry following the **2008 financial crisis**. In 2018, for example, the **Trump administration** rolled back parts of the **Dodd-Frank Act** (a key piece of legislation passed after the 2008 crisis), easing regulatory scrutiny on banks with assets under $250 billion, which included SVB.
#    - **SVB**, with assets of around $200 billion at the time of its collapse, was not subject to the same level of oversight as larger banks. This allowed the bank to take on greater risk without the same level of scrutiny that might have been applied to larger, more systematically important institutions.
#
# ### 7. **The Role of Technology and Crypto**
#    - **Tech sector downturn**: Many of SVB's clients were startups in the tech sector, which were heavily impacted by the rise in interest rates. As funding became more expensive and venture capitalists pulled back, these companies struggled to access capital and began withdrawing funds to meet operational expenses.
#    - **Crypto volatility**: Signature Bank had a significant exposure to the **cryptocurrency market**, which was experiencing its own struggles in 2023, including the fallout from major bankruptcies (e.g., **FTX**) and regulatory crackdowns. As crypto-related deposits began to dry up, Signature Bank’s liquidity also became strained, contributing to its collapse.
#
# ### 8. **The Speed of the Crisis**
#    - The speed at which SVB’s crisis unfolded also played a key role. The bank's **failure happened within days**, largely due to the **rapid withdrawal of deposits** triggered by the bank run. The suddenness of the collapse led to panic and the spread of uncertainty across the banking sector.
#    - The **FDIC’s decision to step in** and take control of SVB in early March 2023 helped stem the panic, but the uncertainty around other regional banks continued to fuel concerns.
#
# ### 9. **The Government's Response**
#    - The **FDIC (Federal Deposit Insurance Corporation)** quickly took control of the failed banks (SVB, Signature, etc.), and the **U.S. Treasury** and the **Federal Reserve** took steps to reassure the public, including guaranteeing all deposits above the FDIC’s $250,000 insurance limit. This was an attempt to prevent further panic and stabilize the banking system.
#    - The Fed also announced new emergency lending programs to help banks with liquidity problems.
#
# ### Summary of Key Factors:
# 1. **Rising interest rates** led to **losses on bond portfolios** and forced banks to sell assets at a loss.
# 2. **Bank runs** were triggered by a **loss of confidence**, leading to rapid withdrawals.
# 3. **Lack of diversification** and **poor risk management** left certain banks vulnerable.
# 4. **Concentration in tech and crypto sectors** heightened exposure to sector-specific downturns.
# 5. **Regulatory gaps** allowed smaller banks to take on more risk without adequate oversight.
# 6. **Panic and a lack of liquidity** exacerbated the crisis, leading to more failures.
#
# In conclusion, the banking crisis of 2023, highlighted by the collapse of SVB and Signature Bank, was driven by a combination of poor risk management, rising interest rates, sector-specific downturns, and loss of depositor confidence. The crisis was ultimately contained through government intervention, but it highlighted vulnerabilities in the financial system, particularly in smaller banks and banks with concentrated client bases.
#
# <span style="color: royalblue; font-size: 30px; font-weight: bold;">Credit Sussie</span>
#
# Credit Suisse was somewhat **separate** from the specific wave of the 2023 banking crisis that was triggered by the collapse of Silicon Valley Bank (SVB) and Signature Bank, but it was still very much part of the broader **banking turbulence** and **financial contagion** that followed.
#
# ### Key Differences:
# 1. **Pre-existing Issues at Credit Suisse:**
#    Credit Suisse had been struggling for several years before the 2023 crisis. Unlike SVB or Signature Bank, which were more directly impacted by interest rate hikes and sector-specific problems (tech startups and crypto), Credit Suisse had a series of **long-standing internal issues** that made it vulnerable:
#
#    - **Risk management failures**: Credit Suisse had been plagued by a series of **scandals**, financial mismanagement, and poor risk-taking decisions, including involvement in the collapse of Archegos Capital (a massive hedge fund blowup in 2021) and the **Greensill Capital** debacle. Both of these events cost the bank billions and severely damaged its reputation.
#    - **Low profitability**: The bank was struggling with profitability and had a history of weak earnings growth, even before the broader economic pressures of 2022 and 2023.
#    - **Lack of investor confidence**: Confidence in Credit Suisse had been eroding for years, and by early 2023, it was already facing heightened concerns about its financial health and stability. The bank's stock was trading at a significant discount, and there were persistent rumors of potential failure.
#
# 2. **SVB and Signature Bank’s Direct Impact:**
#    The collapse of **SVB** and **Signature Bank** was much more directly related to the **interest rate hikes** and their effects on liquidity, as well as specific sectoral exposure (tech and crypto). These banks had more acute vulnerabilities linked to their deposit base and asset-liability mismatches, with SVB being especially vulnerable to **tech sector downturns** and **venture capital pullbacks**.
#
#    - **SVB's collapse** in particular set off a chain reaction and a **loss of confidence** in the broader banking system, which caused a **marketwide panic** about financial stability.
#    - **Signature Bank**'s collapse also contributed to the panic, as it had a significant amount of exposure to **crypto**, a sector that had already been facing turmoil due to the FTX collapse and other crypto market challenges.
#
# ### The Role of Credit Suisse in the Crisis:
#
# While Credit Suisse was not **directly triggered** by the issues that took down SVB or Signature, it was still impacted by the broader environment of **loss of confidence** in the banking system that these failures precipitated. This panic, combined with Credit Suisse's own **financial instability**, created a perfect storm.
#
# - In **March 2023**, Credit Suisse faced a **liquidity crisis** and a **sharp decline in stock price**, driven by fears that it might be the next major bank to fail. Investors were concerned about its financial position, especially after a negative report from **Saudi National Bank**, which was its largest shareholder, announced it would not provide further funding.
#
# - The **Swiss National Bank (SNB)** stepped in with a **$54 billion emergency liquidity loan** to stabilize Credit Suisse, but this wasn’t enough to restore confidence. A few days later, **UBS** agreed to acquire Credit Suisse in a **government-brokered deal** to prevent a full-scale collapse of the bank and potential market contagion.
#
# ### The Contagion Effect:
#
# Credit Suisse’s collapse was **part of the broader contagion** that stemmed from the wave of instability caused by the failures of SVB and Signature Bank. The panic around these U.S. banks spread across financial markets and affected **European banks**, including Credit Suisse, due to:
#
# - **Global interconnectedness**: Financial institutions are deeply interconnected across borders, and the collapse of major banks in one region (the U.S.) can trigger fears of a broader global contagion.
# - **Loss of confidence in the banking sector**: The failures of SVB and Signature Bank raised fears that other banks—especially those with liquidity or risk management issues—might also be in trouble. This triggered a loss of confidence in banks globally, leading to increased pressure on stocks and the financial stability of banks like Credit Suisse.
# - **General market conditions**: Rising interest rates, inflation, and economic uncertainties added stress to the financial system, and Credit Suisse, already struggling with its own set of problems, found itself caught in this wave of panic.
#
# ### Conclusion:
#
# While Credit Suisse’s problems were largely **self-inflicted** (due to years of mismanagement and poor risk decisions), its collapse in 2023 was still part of the broader **wave of banking instability** that was set off by the failures of SVB and Signature Bank. The contagion from those U.S. banks, combined with Credit Suisse’s pre-existing vulnerabilities, triggered a **crisis of confidence** in the global financial system, eventually leading to its forced acquisition by UBS.
#
# In short, Credit Suisse's troubles were rooted in its own long-standing issues, but the broader **banking crisis**—sparked by SVB's collapse—played a significant role in exacerbating its downfall.
# ###### Credit: ChatGPT

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="co"></a>
#
# <span style="color: darkviolet; font-size: 30px; font-weight: bold;">Crowding Out!</span>
#
#
# ### &diams; <span style="color: red;">How Fiscal Policy Can Crowd Out Privae Investment?</span>
#
# #### Ramifications:
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">&#9734;Deficit Spending (increase Gov't expenditures to fight recession)</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: teal;">Drive up Interest Rates (via act of borrowing to finance deficit)</span><br>
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: blue;">Gov't must compete along with the private sector for capital funds in the lending market</span><br>
#             <div style="margin-left: 40px; font-size: 18px;">
#                 &#9657; <span style="color: darkviolet;">From that observation alone, we can see how such deficit spending can only indeed lead to the crowding out the business investment</span><br>
#                 &#9657; <span style="color: darkviolet;">Business Investment Falls</span><br>
#             </div>
#         </div>
#         <div style="margin-left: 30px; font-size: 18px;">
#              &#9758; <span style="color: orange; font-weight: bold;">Fiscal Stimulus Fully or Partially Offset</span>
#         </div>
#     </div>
# </div><br>
#
# Fiscal policy can "crowd out" private investment when government spending or borrowing increases to the point that it negatively affects private sector investment. This typically occurs through the mechanism of rising interest rates. Here's a detailed explanation of how this happens:
#
# ### 1. **Increased Government Borrowing:**
#    When the government increases its spending, especially in times of budget deficits, it often borrows money to finance the difference between its revenue and its expenditures. This is typically done by issuing government bonds.
#
#    - **Government borrowing increases demand for loanable funds:** As the government borrows more, it competes with private borrowers in the financial markets for available funds.
#    - **Demand for funds increases:** With more borrowers in the market (the government being a major one), the total demand for money (or loanable funds) rises.
#
# ### 2. **Rising Interest Rates:**
#    The increased demand for funds (due to higher government borrowing) tends to drive up interest rates, assuming the supply of loanable funds doesn't increase correspondingly.
#
#    - **Interest rates rise:** As demand for money increases, lenders can charge higher interest rates because they have more borrowers competing for the same pool of funds.
#
# ### 3. **Higher Cost of Borrowing for Private Sector:**
#    When interest rates rise, it becomes more expensive for private businesses to borrow money to fund their own investments, such as purchasing new equipment, expanding operations, or undertaking research and development.
#
#    - **Private investment becomes less attractive:** Higher interest rates increase the cost of capital for businesses. In response, businesses may reduce or postpone their investment plans, as the return on investment (ROI) needed to justify borrowing becomes harder to achieve.
#
# ### 4. **Crowding Out:**
#    This reduction in private investment due to the higher cost of borrowing is referred to as "crowding out." Essentially, the government's increased borrowing reduces the funds available for private businesses to invest, leading to a reduction in overall private investment.
#
# ### 5. **Possible Long-Term Effects:**
#    Over time, if government spending remains high and borrowing continues to increase, the crowding-out effect could lead to a sustained reduction in private sector investment. This might slow down economic growth, as private investment is a key driver of productivity, innovation, and job creation.
#
# ### Example:
#
# Imagine that a government launches a large infrastructure program, and to finance it, it borrows heavily by issuing bonds. The demand for loanable funds rises because the government is absorbing a large portion of the available funds. This increases interest rates, making it more expensive for a tech startup, for instance, to get a loan to expand its operations. As a result, the startup might decide to delay its expansion, leading to a reduction in private sector investment.
#
# ### How to Mitigate Crowding Out:
#
# - **Monetary Policy Response:** The central bank could lower interest rates (e.g., through open market operations) to offset the increase in rates caused by government borrowing, which could help stimulate private investment even in the face of higher government spending.
# - **Well-Targeted Government Spending:** If government spending is directed toward projects that enhance productivity (like education, infrastructure, or research), the economy as a whole may benefit, making it easier for private investment to thrive alongside public investment.
#
# ### Conclusion:
# Fiscal policy crowds out private investment mainly through higher government borrowing, which increases interest rates, making it more expensive for businesses to invest. While this is a typical concern in economies with high levels of government debt, the overall impact on private investment depends on the size of the fiscal expansion, the responsiveness of monetary policy, and the state of the economy.
#
# ###### Credit: ChatGPT

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>
