# %% [markdown]
# <a id="top"></a>
# ### <span style="color: red;"></span>

# %% [markdown]
# ### &diams; <span style="color: green;">Highlight </span>
# <ul style="margin-left: 40px; color: green; font-size:20px;">
#     <li style="color: darkviolet; font-style: italic;">Monetary Policy vs Fiscal Policy<a href="#mpfp">🔗</a></li>
#     <li style="color: deepskyblue; font-style: italic;">Interest Rate<a href="#ir">🔗</a></li>
#      <li style="color: freen; font-style: italic;">Money Functionality<a href="#mf">🔗</a></li>
#      <li style="color: brown; font-style: italic;">Money Demand<a href="#md">🔗</a></li>
#     <li style="color: cornflowerblue; font-style: italic;">Money History<a href="#mh">🔗</a></li>
#     <li style="color: deeppink; font-style: italic;">Central Bank Functionality<a href="#cbf">🔗</a></li>
#     <li style="color: cyan; font-style: italic;">Monetary Policy vs Fiscal Policy<a href="#mpfp">🔗</a></li>

# %% [markdown]
# <a id="mpfp"></a>
# <span style="color: darkviolet; font-size: 50px; font-weight: bold;">Monetary Policy vs Fiscal Policy</span>
#
# <span style="color: royalblue; font-size: 40px; font-weight: bold;">&#9996;Monetary Policy as a fine-Tuning Policy Tool</span>
#        <div style="margin-left: 20px; font-size: 30px;">
#          <span style="color: teal;">1. Be Implemented Faster & More Flexibly than Fiscal Policy</span>
#           <div style="margin-left: 30px; font-size: 30px;">
#          &#9983;&nbsp;<span style="color: pink;font-size: 20px;font-weight:bold;">Fiscal Policy, such as pass a legislation, requires the approval of a Congress or a Parliament, President or Prime Minister</span><br>
#          &#9983;&nbsp;<span style="color: pink;font-size: 20px;font-weight: bold;">Monetary Policy, requires just the central bank to enact</span>
#          &#9992;&nbsp;<span style="color: deeppink;font-size: 20px;font-style:italic;">Fiscal Policy would activate, when the situation is severe and prolonged, such as recession!</span>
#          </div><br>
#          <span style="color: teal;font-size: 30px;">2. Monetary Policy More EFFECTIVE Fighting Inflation (You can't push on a string)</span>
#           <div style="margin-left: 30px;font-size: 25px">
#               <span style="color: darkorange;">&#10047; &nbsp; a. Push on a string</span><br>
#                  <div style="margin-left: 50px;font-size: 20px">
#                      <span style="color: darkturquoise;font-wieght:bold;">&#8594; &nbsp; Monetary Policy will fail when ppl are not ready for it.</span><br>
#                        </div>
#                     <div style="margin-left: 58px;font-size: 25px">
#                       <span style="color: darkviolet;font-wiehgt:bold;">&nbsp; Example:</span><br>
#                       </div>
#                         <div style="margin-left: 80px;font-size: 20px">
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Interest Rate Cut may not increase investment as ppl confidence may not return yet</span><br>
#                                </div>
#               <span style="color: darkorange;">&#10047; &nbsp; b. Pull on a string</span><br>
#                   <div style="margin-left: 50px;font-size: 20px">
#                      <span style="color: darkturquoise;font-wieght:bold;">&#8594; &nbsp; Monetary Policy will succeed in contractionary policy </span><br>
#                        </div>
#                     <div style="margin-left: 58px;font-size: 25px">
#                       <span style="color: darkviolet;font-wiehgt:bold;">&nbsp; Example:</span><br>
#                       </div>
#                         <div style="margin-left: 80px;font-size: 20px">
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Interest Rate Hike by Central Bank Usually would work to reduce investment</span><br>
#                             </div>
#             </div>
# </div>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="mp"></a>
#
# <span style="color: darkviolet; font-size: 30px; font-weight: bold;">Monetary Policy</span>
#
# ### &diams; <span style="color: blue;">Monetary policy is a tool implemented by a nation's central bank. For instance, the Fed (US), Bank of Japan (JPN), European Central Bank (EU of Nations) </span>
#
# <div style="margin-left: 40px;">
#    <span style="color: Fuchsia; font-size: 20px;font-weight: bold;">Fight Recession</span>
#    <div style="margin-left: 20px;font-size: 15px">
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Expansionary Monetary Policy</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">Increase Money Supply</span><br>
#           &#9678; <span style="color: teal; font-size:20px; font-weight:bold; font-style:italic;">Decrease Interest Rates</span><br>
#             <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#10032; <span style="color: orange;">Direct effect: Investment increases</span><br>
#                 <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#10033; <span style="color: brown;font-weight:bold;">GDP increases!!!</span>
#            </div>
#            &#10032; <span style="color: orange;">Indirect effect: Export increases (the nation's currency/rate is weakened)</span><br>                 <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#10033; <span style="color: brown;font-weight:bold;">GDP increases!!!</span>
#            </div>
#        </div>
#    </div>
# </div>
# <div style="margin-left: 40px;">
#    <span style="color: orange; font-size: 20px;font-weight: bold;">Exchange Rate</span>
#    <div style="margin-left: 20px;font-size: 15px">
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Price of one nation's currency in terms of another nation's currency</span><br>
#        &#8594; <span style="color: darkpurple;font-weight:bold;">When Interest Rates Fall</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9978; <span style="color: darkturquoise; font-weight:bold;">Foreign Investment from foreigners to the nation Falls (i.e. go to other countries where the interest rates are higher relatively)</span><br>
#           &#9978; <span style="color: darkturquoise; font-weight:bold;">Demand for Domestic Currency Falls</span><br>
#           &#9978; <span style="color: darkturquoise; font-weight:bold;">Demand for Foreign Currency may increase, if interest rates in foreign country is relatively higher</span><br>
#             <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#10032; <span style="color: orange;">Weaken Domestic Exchange Rate (foreigners are demanding fewer dollars as to how a weaker currency might actually stimulate)</span><br>
#             </div>
#        </div>
#    </div>
# </div>
#
# <div style="margin-left: 40px;">
#    <span style="color: blue; font-size: 20px;font-weight: bold;">Net Export</span>
#    <div style="margin-left: 20px;font-size: 15px">
#        &#8594; <span style="color: darkpurple;font-weight:bold;">When Interest Rates Fall</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">Exports Increase</span><br>
#           &#9678; <span style="color: teal;">Imports Decrease</span><br>
#             <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#10032; <span style="color: orange;">Net Exports Rise</span><br>
#               &#10032; <span style="color: brown;font-weight:bold;">GDP increases!!!</span>
#             </div>
#        </div>
#    </div>
# </div>
# </div><br>
#
# <div style="margin-left: 40px;">
# <span style="color: Fuchsia; font-size: 20px;font-weight: bold;">Fight Inflation (Demand-Pull)</span>
#    <div style="margin-left: 20px;font-size: 15px">
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Contractionary Monetary Policy</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">Decrease Money Supply</span><br>
#           &#9678; <span style="color: teal; font-size:20px; font-weight:bold; font-style:italic;">Increase Interest Rates</span><br>
#             <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#10032; <span style="color: orange;">Direct effect: Investment reduced</span><br>
#                 <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#10033; <span style="color: brown;font-weight:bold;">GDP reduced!!!</span>
#            </div>
#            &#10032; <span style="color: orange;">Indirect effect: Export decreases (the nation's currency/rate is strengthed)</span><br>                 <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#10033; <span style="color: brown;font-weight:bold;">GDP decreases!!!</span><br>
#               &#10033; <span style="color: brown;font-weight:bold;">Inflation reduces</span>
#            </div>
#        </div>
#    </div>
# </div>
# </div>
#
# ### &diams; <span style="color: red;">What are some of the various adjustments that occur on the export and import sides of the net export equation itself when interest rates fall?</span>
#
# #### Reasons:
#
# <div style="margin-left: 40px;">
#     <span style="color: darkviolet; font-size: 20px; font-weight: bold;">Exports Increase</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: teal;">Expansionary</span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: teal;">Domestic products are easier to sell to other nations as they are cheapter now due to the fall of the currency exchange rates</span><br>
#         </div>
#         <div style="margin-left: 30px; font-size: 18px;">
#             <!-- &#9758; <span style="color: brown; font-weight: bold;">Fight Recession</span> -->
#         </div>
#     </div>
#     <span style="color: darkviolet; font-size: 20px; font-weight: bold;">Imports Decrease</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         <!--&#8594; <span style="color: gray;"></span><br> -->
#         <div style="margin-left: 20px; font-size: 18px;">
#             &#9678; <span style="color: gray;">Domestic demand for foreign products decreased as prices of foreign products are higher now.</span><br>
#         <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#10033; <span style="color: brown;font-weight:bold;">GDP increases!!!</span>
#            </div>
#         </div>
#     </div>
# </div>
# </div>
#
# ### &#9835; <span style="color: dodgerblue;">Discretionary Monetary Policy is all about manipulating both Interest Rates and Exchange Rates as the TWO key components impacting on Business and Investment environments.</span>
# <div style="margin-left: 30px;font-size: 18px; font-style: bold;">
#               &#9971; <span style="color: orange;font-weight:bold;">Interest Rates</span><br>
#               &#9971; <span style="color: orange;font-weight:bold;">Exchange Rates</span><br>
# </div>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="ir"></a>
# <span style="color: deepskyblue; font-size: 40px; font-weight: bold;">Summary</span>
#
# **Monetary policy** and **fiscal policy** are two critical tools used by governments to manage a country's economy. Though they are often used in tandem, they operate in fundamentally different ways and are managed by different institutions. Here's a detailed comparison and explanation of both:
#
# ### **1. Monetary Policy**
#
# **Definition:**
# Monetary policy refers to the process by which a country’s central bank, such as the **Federal Reserve** in the U.S., controls the supply of money, interest rates, and credit in an economy to achieve specific macroeconomic goals, such as controlling inflation, managing employment levels, and promoting economic growth.
#
# **Key Tools:**
# - **Interest Rates:** The central bank controls short-term interest rates, such as the **federal funds rate** (in the U.S.). By raising or lowering these rates, the central bank can influence borrowing and spending in the economy. Lower interest rates encourage borrowing and investment, while higher rates discourage excessive borrowing and help cool down inflationary pressures.
#
# - **Open Market Operations (OMOs):** This involves the buying and selling of government bonds in the open market. Buying bonds injects money into the economy (expansionary monetary policy), while selling bonds takes money out of circulation (contractionary monetary policy).
#
# - **Reserve Requirements:** The central bank can change the reserve requirements for commercial banks, dictating how much money banks must hold in reserve rather than lending out. Lowering the reserve requirement can increase lending and stimulate economic activity, while raising it can reduce lending.
#
# - **Quantitative Easing (QE):** A non-traditional monetary policy tool, QE involves the central bank purchasing long-term government securities or other financial assets to inject liquidity into the economy when traditional interest rate cuts are no longer effective.
#
# **Goals of Monetary Policy:**
# - **Price Stability:** Keeping inflation in check is one of the central goals. Most central banks aim for a target inflation rate (e.g., 2% in many countries).
# - **Full Employment:** Ensuring that as many people as possible have jobs.
# - **Economic Growth:** Promoting stable and sustainable growth.
# - **Exchange Rate Stability:** In some cases, controlling or influencing the value of a currency.
#
# **Example of Monetary Policy in Action:**
# During the 2008 global financial crisis, the Federal Reserve cut interest rates to near-zero levels and initiated several rounds of **quantitative easing** to stimulate the U.S. economy. This kept borrowing costs low and tried to increase the money supply to support financial institutions and stimulate demand.
#
# ---
#
# ### **2. Fiscal Policy**
#
# **Definition:**
# Fiscal policy involves the use of government spending and taxation to influence the economy. Unlike monetary policy, which is managed by the central bank, fiscal policy is the responsibility of the **government**—specifically the **legislature** (e.g., the U.S. Congress) and the **executive branch** (e.g., the President).
#
# **Key Tools:**
# - **Government Spending:** The government can either increase or decrease its spending on infrastructure, defense, healthcare, education, and other services. Increased government spending can stimulate economic growth by creating jobs and boosting demand for goods and services.
#
# - **Taxation:** Governments can raise or lower taxes. Lowering taxes leaves individuals and businesses with more disposable income, encouraging consumer spending and business investment. Raising taxes can have the opposite effect, slowing down demand and consumption.
#
# - **Transfer Payments:** This includes payments from the government to individuals, such as unemployment benefits or Social Security. These payments can be increased during times of economic downturn to support households and stimulate demand.
#
# - **Budget Deficits and Surpluses:** Fiscal policy also involves decisions about whether the government runs a budget deficit (spending more than it takes in) or a surplus (spending less than it takes in). Running a deficit can stimulate the economy, while a surplus can be used to reduce national debt.
#
# **Goals of Fiscal Policy:**
# - **Economic Stability:** By adjusting spending and taxes, governments can smooth out economic cycles, mitigating recessions or overheating during booms.
# - **Reducing Unemployment:** During times of high unemployment, governments may increase spending or cut taxes to boost demand and job creation.
# - **Control Inflation:** In times of high inflation, governments may reduce spending or increase taxes to cool down the economy.
# - **Redistribution of Wealth:** Through progressive taxes and social welfare programs, fiscal policy can address income inequality.
#
# **Example of Fiscal Policy in Action:**
# During the COVID-19 pandemic, many governments (including the U.S.) implemented large fiscal stimulus packages, increasing government spending on unemployment benefits, small business support, and direct payments to individuals. This helped counteract the economic slowdown caused by lockdowns and the broader impact of the pandemic.
#
# ---
#
# ### **Key Differences Between Monetary Policy and Fiscal Policy**
#
# | **Aspect**                | **Monetary Policy**                              | **Fiscal Policy**                                  |
# |---------------------------|--------------------------------------------------|----------------------------------------------------|
# | **Authority**              | Managed by a central bank (e.g., the Federal Reserve in the U.S.) | Managed by the government (executive and legislative branches) |
# | **Tools**                  | Interest rates, open market operations, reserve requirements, quantitative easing | Government spending, taxation, transfer payments, budget deficits/surpluses |
# | **Focus**                  | Money supply, inflation control, interest rates, and financial conditions | Government spending and taxation policies to influence demand |
# | **Speed of Impact**        | Often quicker but depends on interest rate changes and market expectations | Takes longer to implement (e.g., passing legislation) and has direct effects on the economy |
# | **Main Goal**              | Price stability, full employment, economic growth, and financial system stability | Economic growth, reducing unemployment, income redistribution, managing public debt |
# | **Flexibility**            | More flexible, as central banks can adjust monetary policy quickly | Less flexible, as fiscal policy changes require legislative action and political agreement |
#
# ---
#
# ### **Complementary Nature of Monetary and Fiscal Policy**
#
# While **monetary policy** is primarily about managing the money supply and financial conditions, **fiscal policy** focuses on government spending and taxation. In many situations, both types of policies are used together to achieve economic goals:
#
# - During a **recession**, central banks might cut interest rates and increase the money supply (monetary policy), while governments might increase spending and lower taxes (fiscal policy) to boost demand.
#
# - During periods of **inflation**, central banks may raise interest rates and reduce the money supply, while governments may reduce spending or raise taxes to cool the economy.
#
# However, the coordination between monetary and fiscal policies can sometimes be difficult due to differing political pressures. For example, while central banks often aim for long-term stability (independent of short-term political interests), fiscal policy may be influenced by the current government's priorities, which can result in tension between the two.
#
# ---
#
# ### **Summary of Key Differences:**
#
# - **Monetary Policy** is controlled by the central bank and uses tools like interest rates, money supply, and credit controls to stabilize inflation and promote economic growth.
# - **Fiscal Policy** is controlled by the government and uses taxation and government spending to influence overall economic demand, employment, and growth.
#
# Both policies are essential for managing an economy, and their effectiveness depends on the timing and coordination of their use. They are especially important during economic crises when one or both might be used to stabilize and recover the economy.
#
# <div style="margin-left: 0px;font-size: 15px">
#    <span style="color: green;">&#10047; &nbsp; Defined as Price of Money</span><br>
#    <span style="color: green;">&#10047; &nbsp; The amount of interest paid per unit of time</span><br>
#    <span style="color: green;">&#10047; &nbsp; Expressed as Percentage of Amount Borrowed</span><br>
# </div>
#
# ### &diams; <span style="color: blue;">Not "the interest rate" but "many", associated with types of lending instruments, aka Load Maturity</span>
#
#
# <div style="margin-left: 20px;font-size: 15px">
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Gov't Bonds</span><br>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Lines of Credit</span><br>
#       &#9752; <span style="color: dodgerblue;font-weight:bold;">Construction Loands</span><br>
#       &#9752; <span style="color: dodgerblue;font-weight:bold;">Home Mortgages</span><br>
# </div>
#
#
# <div style="margin-left: 40px;">
#    <span style="color: Fuchsia; font-size: 20px;font-weight: bold;">Interest Rate Type</span>
#    <div style="margin-left: 20px;font-size: 15px">
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Fixed</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">Morgage interest rate (usually the choice) </span><br>
#        </div>
#            <!-- <div style="margin-left: 30px;font-size: 18px"> -->
#             <!-- &#9758; <span style="color: brown;font-weight:bold;">Fight Recession</span> -->
#            <!-- </div> -->
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Adjustable</span>
#         <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">Credit card interest rate</span><br>
#        </div>
#            <!-- <div style="margin-left: 30px;font-size: 18px; font-style: bold;"> -->
#            <!--  &#9758; <span style="color: brown;font-weight:bold;">Fight Inflation</span> -->
#            <!-- </div> -->
#     </div>
# </div>
#
#
# ### &diams; <span style="color: red;">Why are there different interest rates?</span>
# #### Reasons:
#
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">1. Load Maturity</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: teal;">The Longer the Loan, The Higher the Rate</span><br>
#     </div>
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">2. Default Risk</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: teal;">Govn't bonds are the safest, if countries are strong and stable -> Low Default risk</span><br>
#         &#8594; <span style="color: teal;">Shaky Businesses are one of the the most risky ones -> High default risk</span><br>
#         <div style="margin-left: 20px; font-size: 18px;">
#         &#10161; <span style="color: purple;">Interest rate rises as risk rises</span><br>
#         </div>
#     </div>
#      <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">3. Liquidity</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: teal;">Cash -> High liquidity</span><br>
#         &#8594; <span style="color: teal;">Bitcoin -> Low liquidity</span><br>
#         <div style="margin-left: 20px; font-size: 18px;">
#         &#10161; <span style="color: purple;">The less liquid, the higher rate</span><br>
#         </div>
#     </div>
# </div>
#
# ## &diams; <span style="color: orange;font-weight:bold;">Nominal vs Real Interest Rate</span>
# #### Reasons:
#
# <div style="margin-left: 40px;">
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">Nominal Interest Rate</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: teal;">Measures the yield in dollars per year, per dollar of investment</span><br>
#     </div>
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">Real Interest Rate</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: teal;">Corrects for inflation</span><br>
#         &#8594; <span style="color: teal;">Calculated as Nominal Interest Rate minus Inflation rate</span><br>
#         $$
# r_{\text{real}} = r_{\text{nominal}} - r_{\text{inflation}}
# $$
#     </div>
# </div>
# <div style="margin-left: 40px;">
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">Inflation erodes the real return</span>
#     <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: teal;">When inflation rate > Nominal Interest Rate</span><br>
#         <div style="margin-left: 20px; font-size: 18px;">
#         &#10161; <span style="color: purple;">Negative Real Interest Rate!!</span><br>
#         </div>
#     </div>
# </div>
#
#
#
#
# ## Key Takeaway?
# ### <span style="font-size: 28px; font-weight: bold;">&#9788;</span> <span style="color: deepskyblue;">Be aware of the Macroeconomic environment so as to avoid situation as Negative Real Interest Rate underneath the surface.</span>
#
# ### <span style="font-size: 28px; font-weight: bold;">&#9788;</span> <span style="color: deepskyblue;">Always focus on the Real Return</span>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="mf"></a>
#
# <span style="color: green; font-size: 40px; font-weight: bold;">Money Functionality</span>
#
# <div style="margin-left: 0px;font-size: 15px">
#    <span style="color: green;">&#10047; &nbsp; Defined as cash in the pocket</span><br>
#    <span style="color: green;">&#10047; &nbsp; In a broader and general sense, it is anything that can be widely used and and accepted in exchange for other goods and services</span><br>
# </div>
#
# ### In practice, there are THREE kinds of money:
# <div style="margin-left: 20px;font-size: 15px">
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Commodity (gold nuggets)</span><br>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Bank (checkbook)</span><br>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Paper (Fiat) (dollar / yen / ,,,)</span><br>
# </div><br>
#
#
# <div style="margin-left: 0px;">
#    <span style="color: pink; font-size: 20px;font-weight: bold;">Important Concepts</span>
#    <div style="margin-left: 20px;font-size: 15px">
#        &#8594; <span style="color: darkpurple;font-weight:bold;">Liquidity</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">How quickly an asset can be converted into cash</span><br>
#        </div>
#            <div style="margin-left: 30px;font-size: 18px">
#             &#9758; <span style="color: brown;font-weight:bold;">Illiguid: houses, cars</span><br>
#             &#9758; <span style="color: brown;font-weight:bold;">Liguid: cash, gold</span><br>
#            </div>
#      </div>
# </div><br>
#
# <div style="margin-left: 0px;">
#    <span style="color: Fuchsia; font-size: 20px;font-weight: bold;">THREE Money Funtionalities</span>
#    <div style="margin-left: 20px;font-size: 15px">
#        &#8594; <span style="color: darkpurple;font-weight:bold;">1. Medium of Exchange</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">W/O money, barter system would be the way of exchanging goods and services</span><br>
#        </div>
#        &#8594; <span style="color: darkpurple;font-weight:bold;">2. A unit of account / Standard of Value</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">Money expresses the rate at which goods can be exchanged</span><br>
#        </div>
#         &#8594; <span style="color: darkpurple;font-weight:bold;">3. A Store of Value</span><br>
#        <div style="margin-left: 20px;font-size: 18px">
#           &#9678; <span style="color: teal;">Money doesn't perform this very well</span><br>
#             <div style="margin-left: 30px;font-size: 18px">
#           &#9667; <span style="color: darkturquoise;font-weight: bold;">Value does not stay the same due to other factors, such as inflation, foreign policy (exchange rate fluctuations)</span><br>
#           &#9667; <span style="color: darkturquoise;font-weight: bold;">Investment can compensate the disadvantage.</span><br>
#        </div>
#      </div>
# </div>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="md"></a>
# <span style="color: brown; font-size: 40px; font-weight: bold;">Money Demand</span>
#
# ### Two Ways to Interpret:
# <div style="margin-left: 0px;font-size: 20px">
#    <span style="color: green;">&#10047; &nbsp; 1. Transactions Demand</span><br>
#     <div style="margin-left: 10px;font-size: 15px">
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Medium of Exchange</span><br>
#           <div style="margin-left: 20px;font-size: 15px">
#             &#9722; <span style="color: pink;font-weight:bold;">Households need money to buy groceries</span><br>
#             &#9722; <span style="color: pink;font-weight:bold;">Firms need to pay materials and labor</span><br>
#           </div>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Nominal GDP (Total Money Value of All goods and services)</span><br>
#     </div><br>
#    <span style="color: green;">&#10047; &nbsp; 2. Assets Demand (speculative motive)</span><br>
#      <div style="margin-left: 10px;font-size: 15px">
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Readiness to purchase stocks/bonds, when prices are appealing</span><br>
#           <div style="margin-left: 20px;font-size: 15px">
#             &#9722; <span style="color: pink;font-weight:bold;">Holding money has costs/risks:</span><br>
#               <div style="margin-left: 30px;font-size: 15px">
#             &#9992; <span style="color: blueviolet;font-weight:bold;">loss of interests on bonds or returns on stock (investment loss)</span><br>
#             &#9992; <span style="color: blueviolet;font-weight:bold;">loss of purchasing power due to inflation</span><br>
#           </div>
#      </div>
# </div>
#
#
# ### &diams; <span style="color: blue;">What will happen to demand for money if interest rates rise and inflation falls (expectation)?</span>
#
#
# <div style="margin-left: 20px;font-size: 15px">
#        &#9752; <span style="color: darkmagenta;font-weight:bold;">If Interest Rates Rise, asset demand for money should fall (opportunity cost of holding cash rises)</span><br>
#        &#9752; <span style="color: darkmagenta;font-weight:bold;">If the expectation of inflation falling, asset demand for money should increase (less risk of loss of value of monety, lower opportunity cost)</span><br>
# </div>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="mh"></a>
# <span style="color: cornflowerblue; font-size: 40px; font-weight: bold;">Money History</span>
#
# <div style="margin-left: 0px;font-size: 15px">
#    <span style="color: darkorange;">&#10047; &nbsp; Ppl store gold with goldsmiths</span><br>
#    <span style="color: darkorange;">&#10047; &nbsp; Goldsmiths issue receipts</span><br>
#    <span style="color: darkorange;">&#10047; &nbsp; Ppl redeem receipts to buy stuff</span><br>
# </div>
#
# ### &#11088; <span style="color: blue;">Progress to the following...</span>
#
#
# <div style="margin-left: 0px;font-size: 15px">
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Paper Money is born (trade receipts for goods; Receipts function as paper money)</span><br>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Interest-Bearing Accounts(depositors realized they didn't have to leave gold for free; goldsmiths competting for gold; Precursor of Interest-bearing accounts)</span><br>
#       &#9752; <span style="color: dodgerblue;font-weight:bold;">A System of Fractional Reserves (Goldsmiths issue more receipts than they have gold!!) </span><br>
#             <div style="margin-left: 10px;font-size: 15px">
#                          &#9758; <span style="color: fuchsia;font-weight:bold;">Money Supply added</span><br>
# </div>
#
#
# ### &diams; <span style="color: brown;">If the Goldsmiths, as a group, issued two dollars of gold receipts for every one dollar of gold they received: what would be the fractional reserve in this case?</span>
# #### Ans:
# <div style="margin-left: 40px;">
#     <span style="color: Fuchsia; font-size: 20px; font-weight: bold;">50%</span>
# </div>
#
# ## &diams; <span style="color: orange;font-weight:bold;">Money Creation Process</span>
# #### How Banks Create Money: (assumption: 10% reserve requirement and safe to loan the other $90 out)
#
# <div style="margin-left: 10px;">
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">Bank1</span>
#        <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: teal;">Assets: \$100 (Reserve: \$10 | Loans & Investments: \$90}</span><br>
#         &#8594; <span style="color: teal;">Liabilities \$100: (Deposits: \$100)</span><br><br>
#        </div>
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">Bank2 (borrower from bank1 and deposit the loan to bank2)</span>
#        <div style="margin-left: 20px; font-size: 18px;">
#         &#8594; <span style="color: teal;">Assets \$90: (Reserve: \$9 | Loans & Investments: \$81)</span><br>
#         &#8594; <span style="color: teal;">Liabilities \$90): (Deposits: \$90)</span><br>
#     </div>
# </div><br>
#
# <div style="margin-left: 10px;">
#     <span style="color: hotpink; font-size: 18px; font-weight: bold;font-style:italic;">&#9978;New Deposit creation is \$190 (100+90)</span><br>
#     <span style="color: firebrick; font-size: 18px; font-weight: bold;font-style:italic;">&#9978;New Loans and Investmentsn creation is \$171 (90+81)</span><br>
#     <span style="color: darkorange; font-size: 18px; font-weight: bold;font-style:italic;">&#9978;New Reserve creation is \$19 (10+9)</span><br>
# </div>
#
# # &#9981; <span style="color: darkviolet;font-weight:bold;">How to calculate for the money multiplier?</span>
# *Any given reserve requirements set in the banking system of fractuibak reserves and the corresponding rate of money creation*
#
#  $$
# {\text{Money Multiplier}} = {\text{1}} / {\text{Required Reserve}}
# $$
#
# $$
# \text{Money Multiplier} = \frac{1}{\text{Required Reserve}}
# $$
#
# ## &diams; <span style="color: fuchsia;font-weight:bold;">What is Money Multiplier, if reserve requirement equals 10%, 25%, 50%?</span>
#
# <div style="margin-left: 5px;">
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">10%</span>
#        <div style="margin-left: 10px; font-size: 18px;">
#         &#8594; <span style="color: teal;">10</span><br>
#        </div>
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">25%</span>
#        <div style="margin-left: 10px; font-size: 18px;">
#         &#8594; <span style="color: teal;">4</span><br>
#     </div>
#      <span style="color: royalblue; font-size: 20px; font-weight: bold;">50%</span>
#        <div style="margin-left: 10px; font-size: 18px;">
#         &#8594; <span style="color: teal;">2</span><br>
#     </div>
# </div><br>
#
# <span style="color: royalblue; font-size: 40px; font-weight: bold;">&#x1F3E6;The Fed Functionality</span>
#        <div style="margin-left: 10px; font-size: 18px;">
#         &#8594; <span style="color: teal;">Provide financial stability</span><br>
#         &#8594; <span style="color: teal;">Control Bank Reserves</span><br>
#         &#8594; <span style="color: teal;">Set Reserve Requirements</span><br>
#         &#8594; <span style="color: teal;">Set Interest Rates</span><br>
#     </div>
#
# # &#9981; <span style="color: dodgerblue;font-weight:bold;">A Bank Run or A Run on the Bank</span>
#
# <div style="margin-left: 5px;">
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">A Band Run / A Run on the Bank</span>
#        <div style="margin-left: 10px; font-size: 18px;">
#         &#8594; <span style="color: teal;">Too many bank depositers demand their money at the same time</span><br>
#         &#8594; <span style="color: teal;">Lender of Last Resort (Gov't central bank, the Fed, can lend to private banks under pressure (a banker's bank)</span><br>
#        </div>
# </div><br>
#
#
#
# # &#9925; <span style="color: dodgerblue;font-weight:bold;">Is the proability of a bank run, Higher or Lower, if a Nation's Central Bank Serves as Lender of Last Resort?
# <div style="margin-left: 5px;">
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">Lower</span>
#        <div style="margin-left: 10px; font-size: 18px;">
#         &#8594; <span style="color: teal;">A nation's central bank can lend stability to the private banking system</span><br>
#         &#8594; <span style="color: teal;">Lenders are confident the nation will rescue, if anything goes wrong</span><br>
#        </div>
# </div><br>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="cbf"></a>
# <span style="color: deeppink; font-size: 40px; font-weight: bold;">Central Bank Functionality</span>
#
# <span style="color: royalblue; font-size: 40px; font-weight: bold;">&#x1F3E6;The Fed Functionality</span>
#        <div style="margin-left: 20px; font-size: 30px;">
#          <span style="color: teal;">1. Provide financial stability</span>
#          <span style="color: teal;font-size: 30px;">2. Control Bank Reserves</span>
#          <span style="color: teal;font-size: 30px;">3. Set Reserve Requirements</span>
#           <div style="margin-left: 30px;font-size: 25px">
#               <span style="color: darkorange;">&#10047; &nbsp; a. Setting Reserve Requirement</span><br>
#                  <div style="margin-left: 50px;font-size: 20px">
#                      <span style="color: darkturquoise;font-wieght:bold;">&#8594; &nbsp; The lower the reserve requirement, the higher the money multiplier</span><br>
#                        </div>
#                     <div style="margin-left: 58px;font-size: 25px">
#                       <span style="color: darkviolet;font-wiehgt:bold;">&nbsp; Mission:</span><br>
#                       </div>
#                         <div style="margin-left: 80px;font-size: 20px">
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Rarely used to stimulate economy</span><br>
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Primary function is to ensure stability</span><br>
#                             </div>
#               <span style="color: darkorange;">&#10047; &nbsp; b. Setting the DISCOUNT Rate</span><br>
#                   <div style="margin-left: 50px;font-size: 20px">
#                      <span style="color: darkturquoise;font-wieght:bold;">&#8594; &nbsp; Interest Rate Central Bank Charges Banks to Borrow from Central Bank</span><br>
#                        </div>
#                     <div style="margin-left: 58px;font-size: 25px">
#                       <span style="color: darkviolet;font-wiehgt:bold;">&nbsp; Mission:</span><br>
#                       </div>
#                         <div style="margin-left: 80px;font-size: 20px">
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Expand Money Supply, when lower the rate</span><br>
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Contract Moeny Supply, when raising the rate</span><br>
#                             </div>
#               <span style="color: darkorange;">&#10047; &nbsp; Open Market Operations</span><br>
#                   <div style="margin-left: 50px;font-size: 20px">
#                      <span style="color: darkturquoise;font-wieght:bold;">&#8594; &nbsp; Buy / Sell Government Securities to Expand / Contract Money Supply </span><br>
#                        </div>
#                     <div style="margin-left: 58px;font-size: 25px">
#                       <span style="color: darkviolet;font-wiehgt:bold;">&nbsp; Mission:</span><br>
#                       </div>
#                         <div style="margin-left: 80px;font-size: 20px">
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Expand Money Supply (GDP up), as a result of lowering interest rate via purchasing gov't securities</span><br>
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Contract Moeny Supply (GDP down), as a result of raising the rate via selling gov't securities</span><br>
#                             </div>
#                             <span style="color: red;">&#9992; &nbsp; Change Bank Reserves by altering its holdings of gov't securities</span>
#           </div>
#          <span style="color: teal;font-size: 30px;">4. Set Interest Rate / Quantitative Eassing (QE)</span><br>
#          History:
#           <div style="margin-left: 30px;font-size: 25px">
#               <span style="color: darkorange;">&#10047; &nbsp; Initially, focused on setting short run interest rates to implement discretionary monetary policy through the setting rates, like discount rates with the expectation that the long run interest rates, like morgages and bonds, would follow and have the desired monetary policy effect.</span><br>
#               <span style="color: darkorange;">&#10047; &nbsp; QE surfaced, originated by the Fed, and the aftermath of the 2007 financial crisis as lowering short term rates almost zero and the economy still wasn't recovering.</span><br>
#               <span style="color: darkorange;">&#10047; &nbsp; The long end of the bond yield curve (long-term interest rate): the Fed instituted the programe, QE, to attack the jargon of the bond traders.</span><br>
#                     <div style="margin-left: 58px;font-size: 25px">
#                       <span style="color: darkviolet;font-wiehgt:bold;">&nbsp; QE:</span><br>
#                       </div>
#                         <div style="margin-left: 80px;font-size: 20px">
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Central bank buys long-term bonds with newly printed money</span><br>
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Drives up long term bond price, resulting in lowering long-term bond yield.</span><br>
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Stimulates investment and GDP growth</span><br>
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Inversely related to prices today, QE has become an instituionalized part of the tools of monetary policy used by nations to close recessionary and inflationary gaps</span><br>
#                             </div>
#     </div>
# </div>
#
# <span style="color: blue;font-size: 30px;">&#11088;Buy or Sell Bonds to fight for Inflation...</span>
# *When the Fed thinks the economic winds are blowing up a little inflation,*
#
# <div style="margin-left: 0px;font-size: 15px">
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Open Market Committe meeing, the Fed votes to Contract M.S. (interest rates, up; investment, down), to slow down growth to dampen inflation</span><br>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Sell Bonds to tighten M.S. and drive up interest rates!</span><br>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Purchaser writes check to pay for bonds</span><br>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Central Bank Deposits check in private bank</span><br>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Private bank pays ck</span><br>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Bank Reserves Reduced</span><br>
#        &#9752; <span style="color: dodgerblue;font-weight:bold;">Reduced lending</span><br>
#             <div style="margin-left: 10px;font-size: 15px">
#                          &#9758; <span style="color: fuchsia;font-weight:bold;">Money Supply dropped</span><br>
# </div>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# # Recap Monetary Policy:
#
# # &#9981; <span style="color: dodgerblue;font-weight:bold;">How much to increase Gov't Expenditures to Close Recessionary Cap, if Recessionary gap $100 with marginal propensity to save 0.25</span>
#
# <div style="margin-left: 5px;">
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">$25</span>
# </div><br>
#
#  <div style="margin-left: 10px;font-size: 25px">
#                          &#9758; <span style="color: fuchsia;font-weight:bold;">Monetary Policy only works its magic, not directly, but indirectly, thru a key concept: Monetary Transmission Mechanism</span><br>
# </div><br>
#
# <span style="color: green;font-weight:bold;font-size:30px;">&#9925;To close the inflationary gap, will the Fed buy bonds on the Open Market or sell...</span>
# *A change in the M.S. would ripple through the economy in multiple steps and affect real GDP / inflation*
# <div style="margin-left: 5px;">
#     <span style="color: royalblue; font-size: 20px; font-weight: bold;">Money Transmission Mechanism</span>
#        <div style="margin-left: 10px; font-size: 18px;">
#         &#8594; <span style="color: teal;">1. The Central Bank cells bonds</span><br>
#         &#8594; <span style="color: teal;">2. M.S. decreases</span><br>
#         &#8594; <span style="color: teal;">3. Interest Rates increases, Currency increases</span><br>
#         &#8594; <span style="color: teal;">4. Investment decreases, GDP decreases</span><br>
#         &#8594; <span style="color: teal;">5. Export decreases, import increases, GDP decreases</span><br>
#        </div>
# </div><br>

# %% [markdown]
# <span style="color: dodgerblue;">Back To Top</span> <a href="#top">🔗</a>

# %% [markdown]
# <a id="mpfp"></a>
# <span style="color: cyan; font-size: 40px; font-weight: bold;">Monetary Policy vs Fiscal Policy</span>
#
# <span style="color: royalblue; font-size: 40px; font-weight: bold;">&#9996;Monetary Policy as a fine-Tuning Policy Tool</span>
#        <div style="margin-left: 20px; font-size: 30px;">
#          <span style="color: teal;">1. Be Implemented Faster & More Flexibly than Fiscal Policy</span>
#           <div style="margin-left: 30px; font-size: 30px;">
#          &#9983;&nbsp;<span style="color: pink;font-size: 20px;font-weight:bold;">Fiscal Policy, such as pass a legislation, requires the approval of a Congress or a Parliament, President or Prime Minister</span><br>
#          &#9983;&nbsp;<span style="color: pink;font-size: 20px;font-weight: bold;">Monetary Policy, requires just the central bank to enact</span>
#          &#9992;&nbsp;<span style="color: deeppink;font-size: 20px;font-style:italic;">Fiscal Policy would activate, when the situation is severe and prolonged, such as recession!</span>
#          </div><br>
#          <span style="color: teal;font-size: 30px;">2. Monetary Policy More EFFECTIVE Fighting Inflation (You can't push on a string)</span>
#           <div style="margin-left: 30px;font-size: 25px">
#               <span style="color: darkorange;">&#10047; &nbsp; a. Push on a string</span><br>
#                  <div style="margin-left: 50px;font-size: 20px">
#                      <span style="color: darkturquoise;font-wieght:bold;">&#8594; &nbsp; Monetary Policy will fail when ppl are not ready for it.</span><br>
#                        </div>
#                     <div style="margin-left: 58px;font-size: 25px">
#                       <span style="color: darkviolet;font-wiehgt:bold;">&nbsp; Example:</span><br>
#                       </div>
#                         <div style="margin-left: 80px;font-size: 20px">
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Interest Rate Cut may not increase investment as ppl confidence may not return yet</span><br>
#                                </div>
#               <span style="color: darkorange;">&#10047; &nbsp; b. Pull on a string</span><br>
#                   <div style="margin-left: 50px;font-size: 20px">
#                      <span style="color: darkturquoise;font-wieght:bold;">&#8594; &nbsp; Monetary Policy will succeed in contractionary policy </span><br>
#                        </div>
#                     <div style="margin-left: 58px;font-size: 25px">
#                       <span style="color: darkviolet;font-wiehgt:bold;">&nbsp; Example:</span><br>
#                       </div>
#                         <div style="margin-left: 80px;font-size: 20px">
#                              <span style="color: dodgerblue;font-wieght:bold;">&#10027; &nbsp; Interest Rate Hike by Central Bank Usually would work to reduce investment</span><br>
#                             </div>
#             </div>
# </div>
